# %%
import pandas as pd

# %%
reps = pd.read_csv('reps.csv')
reps2 = pd.read_csv('reps2.csv')

# %%
reps.head()
# Out:
#           nameFull careerContributions  \
# 0  Robert Aderholt            $358,030
# 1        Mo Brooks             $21,500
# 2      Gary Palmer             $51,850
# 3    Jeff Sessions            $500,700
# 4   Richard Shelby            $703,746
#
#                                             imageUrl  \
# 0  http://interactives.americanprogressaction.org...
# 1  http://interactives.americanprogressaction.org...
# 2  http://interactives.americanprogressaction.org...
# 3  http://interactives.americanprogressaction.org...
# 4  http://interactives.americanprogressaction.org...
#
#                                                quote stateAbr quoteAnchor  \
# 0  "I fall into the second group of people who be...       AL   fhkltihov
# 1  �I�m also old enough to remember when the same...       AL   xoprlcvym
# 2  �I have a long history of advocating for commo...       AL   jiekrzjyd
# 3  �Although the president has repeatedly claimed...       AL   exkunkipi
# 4  �Important scientific research is ongoing, and...       AL   rqqdxxgsg
#
#                                quoteRef  \
# 0  Daily Mountain Eagle Op-Ed, 12/13/10
# 1               Science Insider, 2/9/11
# 2               Palmer Website, 4/17/15
# 3                   USA Today, 10/13/15
# 4          Weld for Birmingham, 4/29/15
#
#                                          quoteRefUrl
# 0  https://aderholt.house.gov/media-center/in-the...
# 1  http://www.sciencemag.org/news/2011/02/healthy...
# 2  https://palmer.house.gov/media-center/in-the-n...
# 3  http://www.usatoday.com/story/opinion/2015/10/...
# 4  http://weldbham.com/blog/2015/04/29/richard-sh...

# %%
reps2.head()
# Out:
#              District       Party   Representative MarginOfVictory TotalVotes  \
# 0  Alabama District 1  Republican    Bradley Byrne          100.0%    Pending
# 1  Alabama District 2  Republican      Martha Roby            9.3%    246,090
# 2  Alabama District 3  Republican      Mike Rogers           34.2%    284,291
# 3  Alabama District 4  Republican  Robert Aderholt          100.0%    Pending
# 4  Alabama District 5  Republican        Mo Brooks           21.8%    336,368
#
#   MainOpposition  BelieveClimateChange  BirthDate  DateInOffice  \
# 0      Unopposed                   NaN        NaN           NaN
# 1  Nathan Mathis                   NaN        NaN           NaN
# 2    Jesse Smith                   NaN        NaN           NaN
# 3      Unopposed                   NaN        NaN           NaN
# 4      Will Boyd                   NaN        NaN           NaN
#
#    AgeAtTakingOfficeYear     ...       AgeAtTakingOfficeDay  NotableQuote  \
# 0                    NaN     ...                        NaN           NaN
# 1                    NaN     ...                        NaN           NaN
# 2                    NaN     ...                        NaN           NaN
# 3                    NaN     ...                        NaN           NaN
# 4                    NaN     ...                        NaN           NaN
#
#    YearNextElection  115Member  \
# 0               NaN        NaN
# 1               NaN        NaN
# 2               NaN        NaN
# 3               NaN        NaN
# 4               NaN        NaN
#
#    ProportionOfConstituentsWhoBelieveInClimateChange  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    PercentMarginOfPresidentialCandidateVictory  Unnamed: 17  Unnamed: 18  \
# 0                                          NaN          NaN          NaN
# 1                                          NaN          NaN          NaN
# 2                                          NaN          NaN          NaN
# 3                                          NaN          NaN          NaN
# 4                                          NaN          NaN          NaN
#
#    Unnamed: 19  Unnamed: 20
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
#
# [5 rows x 21 columns]

# %%
count = 0

for x in xrange(0,reps.shape[0]):
    for y in xrange(0,reps2.shape[0]):
        if reps.iloc[x]['nameFull'] == reps2.iloc[y]['Representative']:
            print reps.iloc[x]['nameFull']
            count += 1;
            break
print count
# Out:
# Robert Aderholt
# Mo Brooks
# Gary Palmer
# Don Young
# Paul Gosar
# David Schweikert
# Trent Franks
# Rick Crawford
# Bruce Westerman
# Doug LaMalfa
# Tom McClintock
# Jeff Denham
# Devin Nunes
# Ken Calvert
# Dana Rohrabacher
# Darrell Issa
# Duncan Hunter
# Scott Tipton
# Ken Buck
# Doug Lamborn
# Mike Coffman
# Ted Yoho
# Dennis Ross
# Bill Posey
# Mario Diaz-Balart
# Jody Hice
# Tom Price
# Doug Collins
# Barry Loudermilk
# Rick Allen
# Raul Labrador
# Peter Roskam
# Mike Bost
# Rodney Davis
# Randy Hultgren
# John Shimkus
# Todd Rokita
# Larry Bucshon
# Rod Blum
# David Young
# Steve King
# Mike Pompeo
# Thomas Massie
# Steve Scalise
# Bruce Poliquin
# Bill Huizenga
# Justin Amash
# Fred Upton
# Tim Walberg
# Erik Paulsen
# Tom Emmer
# Gregg Harper
# Ann Wagner
# Blaine Luetkemeyer
# Vicky Hartzler
# Ryan Zinke
# Adrian Smith
# Mark Amodei
# Leonard Lance
# Rodney Frelinghuysen
# Steve Pearce
# Peter King
# Lee Zeldin
# John Katko
# Virginia Foxx
# Mark Walker
# David Rouzer
# Richard Hudson
# Robert Pittenger
# Patrick McHenry
# Kevin Cramer
# Steve Chabot
# Bill Johnson
# Bob Gibbs
# Steve Stivers
# Jim Bridenstine
# Markwayne Mullin
# Frank Lucas
# Scott Perry
# Glenn Thompson
# Bill Shuster
# Lou Barletta
# Keith Rothfus
# Joe Wilson
# Jeff Duncan
# Trey Gowdy
# Mick Mulvaney
# Kristi Noem
# Phil Roe
# Diane Black
# Marsha Blackburn
# Louie Gohmert
# Ted Poe
# Joe Barton
# John Culberson
# Michael McCaul
# Mike Conaway
# Mac Thornberry
# Randy Weber
# Bill Flores
# Pete Olson
# Blake Farenthold
# John Carter
# Rob Bishop
# Chris Stewart
# Jason Chaffetz
# Rob Wittman
# Bob Goodlatte
# Morgan Griffith
# Cathy McMorris Rodgers
# David McKinley
# Evan Jenkins
# Paul Ryan
# Jim Sensenbrenner
# Glenn Grothman
# 115

# %%
print reps.shape[0]
# Out:
# 182
